# %%
from scipy.linalg import hadamard, subspace_angles
import numpy as np
from pandas import read_csv

# %%
# using loadtxt()
arr = np.loadtxt("potent.csv",
                 delimiter=",")
display(arr)
# Out:
# array([[ 1.84129760e-01,  1.52808397e-01, -8.27255634e-02,
#          6.08346134e-02,  1.18719198e-01,  1.71115289e-02,
#         -1.64750157e-02,  8.54779326e-02, -1.24377176e-02,
#          5.83071531e-02, -1.61067894e-02,  1.15896504e-01,
#         -4.11822399e-03,  1.93270304e-02, -8.26640405e-03,
#          1.89751946e-02,  1.47012164e-02,  1.88389527e-03,
#         -2.44057256e-02,  4.74100934e-03,  2.47415727e-02,
#         -1.19034387e-02,  2.10567085e-02,  3.78350599e-03,
#         -8.05738325e-03,  2.48428494e-02, -9.34964178e-03,
#          8.07933469e-04],
#        [-1.09269236e-01,  6.36059273e-02, -3.01612164e-01,
#          2.27369958e-01, -2.43648881e-01,  8.46407620e-03,
#         -4.01957922e-01, -2.86377820e-01, -3.51907915e-01,
#         -3.58351721e-01, -1.91127048e-01, -3.73277981e-01,
#         -5.99203285e-02, -2.68835122e-01,  4.43559669e-02,
#         -1.50182269e-01,  3.17517823e-01, -1.27005412e-03,
# ...

# %%
arr.shape
# Out:
# (28, 28)

# %%
np.rad2deg(subspace_angles(arr[:, 0:14], arr[:, 18:]))
# Out:
# array([68.69626663, 42.36056277, 36.90602481, 30.71211744, 21.11645055,
#        14.91694121,  7.17657176,  6.23685189,  4.35043057,  2.10584596])

# %%
arr[:, 14:].shape
# Out:
# (28, 14)
